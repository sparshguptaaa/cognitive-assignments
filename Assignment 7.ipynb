# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Q1. You are a data analyst at an e-commerce company. Your task is to analyze sales data,
# clean and process it, perform staƟsƟcal analysis, and generate visual insights to help the
# business make informed decisions.
# Part I: Randomized Sales Data Generation (NumPy)
# 1. IniƟalize Random Seed
# 2. Generate Sales Data
#  Create a NumPy array of random sales data for 12 months (shape = (12, 4)),
# where each column represents a product category:
#  Electronics, Clothing, Home & Kitchen, Sports.
#  Sales values should be between 1000 and 5000 units per month.
#  The range should be randomized using the seed.
# 3. Convert to DataFrame
#  Convert the cleaned NumPy array into a Pandas DataFrame with:
# i. Columns: Electronics, Clothing, Home & Kitchen, Sports
# ii. Index: Months from Jan to Dec

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
roll_number = 102497004
np.random.seed(roll_number)

sales_data = np.random.randint(1000, 5001, size=(12, 4))
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
categories = ['Electronics', 'Clothing', 'Home & Kitchen', 'Sports']

df = pd.DataFrame(sales_data, columns=categories, index=months)
print(df.head())
print(df.describe())
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         2844      1839            3002    4663
# Feb         2420      1356            1543    2095
# Mar         4552      1744            4875    3370
# Apr         3035      3411            1336    4616
# May         2913      3836            2527    3670
#        Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   3194.166667  2942.916667     3053.833333  3240.250000
# std     913.329855  1239.259050     1304.787745   931.054351
# min    2104.000000  1356.000000     1183.000000  1548.000000
# 25%    2609.750000  1815.250000     2281.000000  2773.750000
# 50%    2950.000000  2975.000000     3042.000000  3247.500000
# 75%    3464.500000  3882.250000     4104.000000  3725.000000
# max    4721.000000  4974.000000     4878.000000  4663.000000

# %% [markdown]
# Part II: Data Manipulation and Analysis (Pandas)
# 1. Display the first 5 rows and summary statstics of the DataFrame.
# 2. Calculate the total sales per category and total sales per month.
# 3. Calculate the average sales growth between consecuƟve months for each category.
# 4. Add the following columns to the DataFrame:
#  Total Sales: Sum of all categories per month.
#  Growth Rate: Percentage change in Total Sales from the previous month.
# 5. Apply a randomized discount:
#  If your roll number is even, apply a 10% discount to the Electronics category.
#  If odd, apply a 15% discount to the Clothing category

# %%
total_sales_per_category = df.sum()
print("Total Sales Per Category:\n", total_sales_per_category)

df['Total Sales'] = df.sum(axis=1)
print("Total Sales Per Month:\n", df['Total Sales'])

df['Growth Rate'] = df['Total Sales'].pct_change() * 100
print("Growth Rate:\n", df['Growth Rate'])

discount_column = 'Electronics' if roll_number % 2 == 0 else 'Clothing'
df[discount_column] *= 0.9 if discount_column == 'Electronics' else 0.85
# Out:
# Total Sales Per Category:
#  Electronics       38868
# Clothing          29112
# Home & Kitchen    36702
# Sports            43803
# dtype: int64
# Total Sales Per Month:
#  Jan    11334
# Feb    10711
# Mar    13591
# Apr    12617
# May    13062
# Jun    13156
# Jul    13435
# Aug    11008
# Sep    16835
# Oct     8971
# Nov    12225
# Dec    11540
# Name: Total Sales, dtype: int64
# Growth Rate:
#  Jan          NaN
# Feb    -5.496735
# Mar    26.888246
# Apr    -7.166507
# May     3.526987
# Jun     0.719645
# Jul     2.120705
# Aug   -18.064756
# Sep    52.934230
# Oct   -46.712207
# Nov    36.272433
# Dec    -5.603272
# Name: Growth Rate, dtype: float64

# %% [markdown]
# Part III: Visualizations (Matplotlib and Seaborn)
# 1. Plot monthly sales trends for each category using line plots.
# 2. Create the following plots:
#  Box plots to show the sales distribution for each category.

# %%
plt.figure(figsize=(10, 6))
for category in categories:
    plt.plot(df.index, df[category], label=category)
plt.legend()
plt.title("Monthly Sales Trends")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

plt.figure(figsize=(8, 6))
sns.boxplot(data=df[categories])
plt.title("Sales Distribution per Category")
plt.show()

# %% [markdown]
# Q.2 For the array: array = np.array([[1, -2, 3],[-4, 5, -6]])
#  i. Find element-wise absolute value
# ii. Find the 25th, 50th, and 75th percentile of flattened array, for each column, for each
# row.
# iii. Mean, Median and Standard Deviation of flattened array, of each column, and
# each row

# %%
array = np.array([[1, -2, 3], [-4, 5, -6]])
print("Element-wise absolute:", np.abs(array))
print("Percentiles:", np.percentile(array, [25, 50, 75]))
print("Mean:", np.mean(array))
print("Median:", np.median(array))
print("Standard Deviation:", np.std(array))
# Out:
# Element-wise absolute: [[1 2 3]
#  [4 5 6]]
# Percentiles: [-3.5 -0.5  2.5]
# Mean: -0.5
# Median: -0.5
# Standard Deviation: 3.8622100754188224

# %% [markdown]
# Q.3 For the array: a = np.array([-1.8, -1.6, -0.5, 0.5,1.6, 1.8, 3.0]).
#  i. Find floor, ceiling and truncated value, rounded values

# %%
a = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])
print("Floor:", np.floor(a))
print("Ceiling:", np.ceil(a))
print("Truncated:", np.trunc(a))
print("Rounded:", np.round(a))
# Out:
# Floor: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling: [-1. -1. -0.  1.  2.  2.  3.]
# Truncated: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded: [-2. -2. -0.  0.  2.  2.  3.]

# %% [markdown]
# Q.4 WAP to swap two elements in a list in Python Using a Temporary Variable.

# %%
lst = [1, 2, 3, 4, 5]
temp = lst[1]
lst[1] = lst[3]
lst[3] = temp
print("Swapped List:", lst)
# Out:
# Swapped List: [1, 4, 3, 2, 5]

# %% [markdown]
# Q.5 Write a Python program to swap two elements in a set by converting it to a list first.

# %%
s = {10, 20, 30, 40, 50}
s = list(s)
s[1], s[3] = s[3], s[1]
s = set(s)
print("Swapped Set:", s)
# Out:
# Swapped Set: {40, 10, 50, 20, 30}
